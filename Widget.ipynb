# %%
# %matplotlib widget
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import root_scalar
from ipywidgets import widgets
from IPython.display import display, clear_output
import ast

# %%
# %run functions.ipynb

# %%
TMD11 = pd.read_csv('TMD11.dat', sep ='\s+', header = None ).drop([8,9,10],axis=1).drop([0,1]).reset_index(drop=True)
TMD11.columns=['eps1', 'epsv', 'eps3', 'epsq', 'void_ratio', 'q', 'p', 'eta']
TMD11 = TMD11.astype(float)
TMD12 = pd.read_csv('TMD12.dat', sep ='\s+', header = None ).drop([8,9,10],axis=1).drop([0,1]).reset_index(drop=True)
TMD12.columns=['eps1', 'epsv', 'eps3', 'epsq', 'void_ratio', 'q', 'p', 'eta']
TMD12 = TMD12.astype(float)
TMD13 = pd.read_csv('TMD13.dat', sep ='\s+', header = None ).drop([8,9,10],axis=1).drop([0,1]).reset_index(drop=True)
TMD13.columns=['eps1', 'epsv', 'eps3', 'epsq', 'void_ratio', 'q', 'p', 'eta']
TMD13 = TMD13.astype(float)
TMD14 = pd.read_csv('TMD14.dat', sep ='\s+', header = None ).drop([8,9,10],axis=1).drop([0,1]).reset_index(drop=True)
TMD14.columns=['eps1', 'epsv', 'eps3', 'epsq', 'void_ratio', 'q', 'p', 'eta']
TMD14 = TMD14.astype(float)
TMD15 = pd.read_csv('TMD15.dat', sep ='\s+', header = None ).drop([8,9,10],axis=1).drop([0,1]).reset_index(drop=True)
TMD15.columns=['eps1', 'epsv', 'eps3', 'epsq', 'void_ratio', 'q', 'p', 'eta']
TMD15 = TMD15.astype(float)
TMD15
# Out:
#           eps1      epsv       eps3       epsq  void_ratio            q  \
# 0     0.000000  0.000000   0.000000   0.000000    0.799326     0.940000
# 1     0.003204  0.003289   0.000042   0.002108    0.799267     4.172563
# 2     0.007819  0.008457   0.000319   0.005000    0.799174    14.408738
# 3     0.019263  0.015504  -0.001880   0.014095    0.799047    28.073466
# 4     0.039772  0.025839  -0.006966   0.031159    0.798861    45.458118
# ..         ...       ...        ...        ...         ...          ...
# 475  24.070536 -5.250102 -14.660319  25.820570    0.893793  1009.208957
# 476  24.122140 -5.254800 -14.688470  25.873740    0.893877  1008.734079
# 477  24.173744 -5.259028 -14.716386  25.926753    0.893953  1007.696880
# 478  24.225348 -5.264196 -14.744772  25.980080    0.894046  1007.454703
# 479  24.276952 -5.268894 -14.772923  26.033250    0.894131  1006.431703
#
#               p       eta
# 0    392.410000  0.000000
# 1    393.471953  0.010604
# 2    396.985878  0.036295
# 3    401.520381  0.069918
# 4    407.264168  0.111618
# ..          ...       ...
# 475  729.982497  1.382511
# 476  729.824204  1.382160
# 477  729.488592  1.381374
# 478  729.447858  1.381120
# 479  729.158611  1.380264
#
# [480 rows x 8 columns]

# %%
results100 = pd.read_csv('results100.csv')
results200 = pd.read_csv('results200.csv')
results300 = pd.read_csv('results300.csv')
results400 = pd.read_csv('results400.csv')


# results100.set_index(['K', 'G', 'm', 'c', 'gamma', 'D', 'k0'], inplace=True)


for results in (results100, results200, results300, results400):

    results['sigm_xx'] = results['sigm_xx'].str[7:-2]
    results['sigm_yy'] = results['sigm_yy'].str[7:-2]
    results['sigm_zz'] = results['sigm_zz'].str[7:-2]
    results['eps_xx'] = results['eps_xx'].str[7:-2]
    results['eps_yy'] = results['eps_yy'].str[7:-2]
    results['eps_zz'] = results['eps_zz'].str[7:-2]
    
    results['sigm_xx'] = results['sigm_xx'].apply(lambda x: ast.literal_eval(str(x))).apply(np.array)
    results['sigm_yy'] = results['sigm_yy'].apply(lambda x: ast.literal_eval(str(x))).apply(np.array)
    results['sigm_zz'] = results['sigm_zz'].apply(lambda x: ast.literal_eval(str(x))).apply(np.array)
    results['eps_xx'] = results['eps_xx'].apply(lambda x: ast.literal_eval(str(x))).apply(np.array)
    results['eps_yy'] = results['eps_yy'].apply(lambda x: ast.literal_eval(str(x))).apply(np.array)
    results['eps_zz'] = results['eps_zz'].apply(lambda x: ast.literal_eval(str(x))).apply(np.array)

# %%
for results in (results100, results200, results300, results400):

    results.set_index(['K', 'G', 'm', 'c', 'gamma', 'D', 'k0'], inplace=True)

# %%
TMD11 = pd.read_csv('TMD11.dat', sep ='\s+', header = None ).drop([8,9,10],axis=1).drop([0,1]).reset_index(drop=True)
TMD11.columns=['eps1', 'epsv', 'eps3', 'epsq', 'void_ratio', 'q', 'p', 'eta']
TMD11 = TMD11.astype(float)
TMD12 = pd.read_csv('TMD12.dat', sep ='\s+', header = None ).drop([8,9,10],axis=1).drop([0,1]).reset_index(drop=True)
TMD12.columns=['eps1', 'epsv', 'eps3', 'epsq', 'void_ratio', 'q', 'p', 'eta']
TMD12 = TMD12.astype(float)
TMD13 = pd.read_csv('TMD13.dat', sep ='\s+', header = None ).drop([8,9,10],axis=1).drop([0,1]).reset_index(drop=True)
TMD13.columns=['eps1', 'epsv', 'eps3', 'epsq', 'void_ratio', 'q', 'p', 'eta']
TMD13 = TMD13.astype(float)
TMD14 = pd.read_csv('TMD14.dat', sep ='\s+', header = None ).drop([8,9,10],axis=1).drop([0,1]).reset_index(drop=True)
TMD14.columns=['eps1', 'epsv', 'eps3', 'epsq', 'void_ratio', 'q', 'p', 'eta']
TMD14 = TMD14.astype(float)
TMD15 = pd.read_csv('TMD15.dat', sep ='\s+', header = None ).drop([8,9,10],axis=1).drop([0,1]).reset_index(drop=True)
TMD15.columns=['eps1', 'epsv', 'eps3', 'epsq', 'void_ratio', 'q', 'p', 'eta']
TMD15 = TMD15.astype(float)




    
lines_labels = [ax[0,0].get_legend_handles_labels()]
lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]
fig.legend(lines, labels)

sliderK = widgets.IntSlider(description='K', value=30, min=20, max=40, step=5, continuous_update=False)
sliderG = widgets.IntSlider(description='G', value=15, min=5, max=25, step=5, continuous_update=False)
sliderm = widgets.FloatSlider(description='m', value=-1.5, min=-2.1, max=-0.9, step=0.3, continuous_update=False)
sliderc = widgets.IntSlider(description='c', value=10, min=6, max=14, step=2, continuous_update=False)
slidergamma = widgets.IntSlider(description='gamma', value=20, min=10, max=30, step=5, continuous_update=False)
sliderD = widgets.FloatSlider(description='D', value=-130, min=-150, max=-110, step=10, continuous_update=False)
sliderk0 = widgets.FloatSlider(description='k0', value=1.2, min=0.8, max=1.6, step=0.2, continuous_update=False)

upperbox = widgets.HBox([sliderK, sliderG, sliderm, sliderc])
lowerbox = widgets.HBox([slidergamma, sliderD, sliderk0])

fig, ax = plt.subplots(2, 2, figsize=(12, 8))
Load_tag = 110



display(widgets.VBox([upperbox,lowerbox]))
def update(value):
    ax[0,0].clear()
    ax[0,1].clear()
    ax[1,0].clear()
    ax[1,1].clear()
    
    TMD_list = ['TMD12','TMD13','TMD14','TMD15']
    for i, TMD in enumerate((TMD12,TMD13,TMD14,TMD15)):
        ax[0,0].plot(TMD['epsq'],TMD ['q'], '--k', label=TMD_list[i],alpha=0.5)
        ax[0,1].plot(TMD['p'], TMD['q'], '--k', label=TMD_list[i],alpha=0.5)
        ax[1,0].plot(TMD['epsq'], TMD['epsv'], '--k', label=TMD_list[i],alpha=0.5)
        ax[1,1].plot(TMD['p'], TMD['epsv'], '--k', label=TMD_list[i],alpha=0.5)

    K = sliderK.value
    G = sliderG.value
    m = round(sliderm.value,1)
    c = sliderc.value
    gamma = slidergamma.value
    D = sliderD.value
    k0 = round(sliderk0.value,1)
    
    for results in (results100, results200, results300, results400):
        get_result = results.loc[K,G,m,c,gamma,D,k0]


        p = (get_result['sigm_xx'] + get_result['sigm_yy'] + get_result['sigm_zz'])/3
        q = get_result['sigm_zz'] - get_result['sigm_xx']
        eps_v = (get_result['eps_xx'] + get_result['eps_yy'] + get_result['eps_zz']) * 100
        eps_q = 2/3 * (get_result['eps_zz'] - get_result['eps_xx']) * 100
        p_total = p[0] + q/3
        u = p_total - p



        ax[0,0].plot(eps_q,q)
        ax[0,1].plot(p,q)
        if Load_tag == 110:
            ax[1,0].plot(eps_q,eps_v)
            ax[1,1].plot(p,eps_v)
        if Load_tag == 100:
            ax[1,0].plot(eps_q,u)
            ax[1,1].plot(p,u)

        ax[0,0].set_xlabel(f'$\epsilon_q$ (%)')
        ax[0,0].set_ylabel("q (kPa)")

        ax[0,1].set_xlabel("p (kPa)")
        ax[0,1].set_ylabel("q (kPa)")
        ax[0,1].set_xlim(0)
        ax[0,1].set_aspect(1, adjustable = 'datalim')
        ax[0,1].apply_aspect()
        xmin01, xmax01, ymin01, ymax01 = ax[0,1].axis() 


        ax[1,0].set_xlabel(f'$\epsilon_q$ (%)')
        if Load_tag == 110:
            ax[1,0].set_ylabel(f'$\epsilon_v$ (%)')
        if Load_tag == 100:
            ax[1,0].set_ylabel(f'u (kPa)')


        ax[1,1].set_xlabel("p (kPa)")
        if Load_tag == 110:
            ax[1,1].set_ylabel(f'$\epsilon_v$ (%)')
        if Load_tag == 100:
            ax[1,1].set_ylabel(f'u (kPa)')    
        ax[1,1].set_xlim(xmin01, xmax01)
        
        
    
    

sliderK.observe(update)
sliderG.observe(update)
sliderm.observe(update)
sliderc.observe(update)
slidergamma.observe(update)
sliderD.observe(update)
sliderk0.observe(update)


update(None)
# Out:
# VBox(children=(HBox(children=(IntSlider(value=30, continuous_update=False, description='K', max=40, min=20, st…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
